# %%
def find_min_cost(fare):
    
#     temp = 200000001  #최대값  10만*200개
    
    for t in range(len(fare)):
        for i in range(len(fare)):
            for j in range(len(fare)):
                if i!=j:
                    temp = min(fare[i][j],fare[i][t]+fare[t][j])
                    fare[i][j] = temp
                if i==j: fare[i][j]=0

    return fare

def solution(n, s, a, b, fares):
    
    node_chk = [-1] * n
    node_fare_info =[[200000001]*n for i in range(n)]
    
    for arr in fares:
        node_fare_info[arr[0]-1][arr[1]-1]=arr[2]
        node_fare_info[arr[1]-1][arr[0]-1]=arr[2]

        
    node_fare_info = find_min_cost(node_fare_info)  #최소 비용으로 정리

    temp = 200000001
    for t in range(n):
        temp = min(temp,node_fare_info[s-1][a-1]+node_fare_info[s-1][b-1],node_fare_info[s-1][t]+node_fare_info[t][a-1]+node_fare_info[t][b-1])
    answer = temp
    return answer


n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# 82

# %%
n=6
node_fare_info = [[-1]*n for i in range(n)]

for arr in fares:
    node_fare_info[arr[0]-1][arr[1]-1]=arr[2]
    node_fare_info[arr[1]-1][arr[0]-1]=arr[2]

node_fare_info
# Out:
# [[-1, -1, 41, 10, 24, 25],
#  [-1, -1, 22, 66, -1, -1],
#  [41, 22, -1, -1, 24, -1],
#  [10, 66, -1, -1, -1, 50],
#  [24, -1, 24, -1, -1, 2],
#  [25, -1, -1, 50, 2, -1]]

# %%
n=6
node_fare_info = {}

for arr in fares:
    node_fare_info[arr[0]-1][arr[1]-1]=arr[2]
    node_fare_info[arr[1]-1][arr[0]-1]=arr[2]

node_fare_info

# %%
def find_min_cost(start,end,fare):
    temp = -1
    for i in range(len(fare)):
        for j in range(i, len(fare)):
            temp = min(temp,fare[i][j])
    return temp

# %%
def find_min_cost(fare):
    
    for t in range(len(fare)):
        for i in range(len(fare)):
            for j in range(i, len(fare)):
                if i!=j:
                    temp = min(fare[i][j],fare[i][t]+fare[t][j])
                    fare[i][j] = temp
                    fare[j][i] = temp
                if i==j: fare[i][j]=0
    return fare

def solution(n, s, a, b, fares):
    inf_value = 20000001 #fare 최대 10만,n 최대 200 
    node_fare_info =[[inf_value]*n for i in range(n)]
    temp = inf_value
    
    for arr in fares:
        node_fare_info[arr[0]-1][arr[1]-1]=arr[2]
        node_fare_info[arr[1]-1][arr[0]-1]=arr[2]

    node_fare_info = find_min_cost(node_fare_info)  #최소 비용으로 정리
    
    for t in range(n):
        temp = min(temp,node_fare_info[s-1][a-1]+node_fare_info[s-1][b-1],node_fare_info[s-1][t]+node_fare_info[t][a-1]+node_fare_info[t][b-1])
        
    answer = temp
    return answer

n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# 82

# %%
#플로이드 와샬(Floyd-Warshall)
def solution(n, s, a, b, fares):
    inf_v = 20000001 #fare 최대 10만,n 최대 200 
    graph =[[inf_v]*n for i in range(n)]
    temp = inf_v
    
    #data 정리
    for arr in fares:
        graph[arr[0]-1][arr[1]-1]=arr[2]
        graph[arr[1]-1][arr[0]-1]=arr[2]

    #플로이드 와샬
    for t in range(len(graph)):
        for i in range(len(graph)):
            for j in range(i, len(graph)):
                if i!=j:
                    graph[i][j] = graph[j][i] = min(graph[i][j],graph[i][t]+graph[t][j])
                if i==j: graph[i][j]=graph[j][i]=0
    
    for t in range(n):
        temp = min(temp,graph[s-1][t]+graph[t][a-1]+graph[t][b-1])
        
    answer = temp
    return answer
n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# 82

# %%
import heapq

def solution(n, s, a, b, fares):
    inf_v = 20000001 #fare 최대 10만,n 최대 200 
    graph ={}
    temp = inf_v
    answer=1
    node=[]
#Graph Setting
    
    for i in fares:
        node.append(i[0])
        node.append(i[1])
    
    for i in set(node):
        graph={ i:{j[1] if} }
    
    graph={i[0]:{i[1]:i[2]} for i in fares}

    return answer
n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# {1, 2, 3, 4, 5, 6}
# {4: {6: 50}, 3: {1: 41}, 5: {1: 24}, 2: {3: 22}, 1: {6: 25}}
# 1

# %%
from collections import defaultdict
import heapq

def solution(n, s, a, b, fares):
    dic = defaultdict(list)
    for st, ed, co in fares:
        dic[st].append((co, ed))
        dic[ed].append((co, st))
    ans = []
    
    for i in range(1, n+1):
        Q = [(0, i)]
        visited = [True] * (n+1)
        dp = [float('inf')] * (n+1)
        dp[i] = 0
        while Q:
            co, des = heapq.heappop(Q)
            if visited[des]:
                visited[des] = False 
                for cost, destination in dic[des]:
                    dp[destination] = min(cost + dp[des], dp[destination])
                    heapq.heappush(Q, (dp[destination], destination))
        ans.append(dp[a] + dp[b] + dp[s])

    return min(ans)

n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# 4
# [inf, 0, inf, inf, inf, inf, inf]
# [inf, 0, inf, inf, 10, inf, inf]
# 3
# [inf, 0, inf, inf, 10, inf, inf]
# [inf, 0, inf, 41, 10, inf, inf]
# 5
# [inf, 0, inf, 41, 10, inf, inf]
# [inf, 0, inf, 41, 10, 24, inf]
# 6
# [inf, 0, inf, 41, 10, 24, inf]
# [inf, 0, inf, 41, 10, 24, 25]
# 1
# [inf, 0, inf, 41, 10, 24, 25]
# [inf, 0, inf, 41, 10, 24, 25]
# 6
# [inf, 0, inf, 41, 10, 24, 25]
# [inf, 0, inf, 41, 10, 24, 25]
# 2
# [inf, 0, inf, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 3
# [inf, 0, 76, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 6
# [inf, 0, 76, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 1
# [inf, 0, 76, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 5
# [inf, 0, 76, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 4
# [inf, 0, 76, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 1
# [inf, 0, 76, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 5
# [inf, 0, 76, 41, 10, 24, 25]
# [inf, 0, 76, 41, 10, 24, 25]
# 1
# [inf, 0, 76, 41, 10, 24, 25]
# ...

# %%
from collections import defaultdict
import heapq

def dijkstra(tr,graph):
    q=[(0,tr)]
    visit=[True]*len(graph)
    dp = [float('inf')]*len(graph)
    dp[tr]=0
    while q:
        fare,destin = heapq.heappop(q)
        if visit[destin] == True: 
            visit[destin]=False
            for key,value in graph[(destin+1)].items():
                if dp[key-1] > value + dp[destin]:
                    dp[key-1] = value + dp[destin]
                heapq.heappush(q,(dp[key-1],key-1))
    return dp            

def solution(n, s, a, b, fares):
    
    graph = defaultdict(dict)
    
#Dict 형태로 graph 
    for stt,end,fare in fares:
        graph[stt][end]=fare
        graph[end][stt]=fare
    inf_v=20000001
    temp_sum = []
    for i in range(n):
        temp_sum += [dijkstra(i,graph)[a-1]+dijkstra(i,graph)[b-1]+dijkstra(i,graph)[s-1]]
    answer = min(temp_sum)

    return answer

n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# 82

# %%
from collections import defaultdict
import heapq

for stt,end,fare in fares:
    dic[stt][end]=fare
    dic[end][stt]=fare
# Out:
# defaultdict(<class 'dict'>, {})
# defaultdict(<class 'dict'>, {4: {1: 10, 6: 50, 2: 66}, 1: {4: 10, 3: 41, 5: 24, 6: 25}, 3: {5: 24, 1: 41, 2: 22}, 5: {3: 24, 6: 2, 1: 24}, 6: {5: 2, 4: 50, 1: 25}, 2: {4: 66, 3: 22}})

# %%
import heapq

def solution(n, s, a, b, fares):

    link = [[] for _ in range(n+1)]
    for x, y, z in fares:
        link[x].append((z, y))
        link[y].append((z, x))

    def dijkstra(start):
        dist = [987654321] * (n + 1)
        dist[start] = 0
        heap = []
        heapq.heappush(heap, (0, start))
        while heap:
            value, destination = heapq.heappop(heap)
            if dist[destination] < value:
                continue
            for v, d in link[destination]:
                next_value = value + v
                if dist[d] > next_value:
                    dist[d] = next_value
                    heapq.heappush(heap, (next_value, d))
        return dist

    dp = [[]] + [dijkstra(i) for i in range(1, n+1)]
    print(dp)
    answer = 987654321
    for i in range(1, n+1):
        answer = min(dp[i][a] + dp[i][b] + dp[i][s], answer)

    return answer

n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# [[], [987654321, 0, 63, 41, 10, 24, 25], [987654321, 63, 0, 22, 66, 46, 48], [987654321, 41, 22, 0, 51, 24, 26], [987654321, 10, 66, 51, 0, 34, 35], [987654321, 24, 46, 24, 34, 0, 2], [987654321, 25, 48, 26, 35, 2, 0]]
# 82

# %%
bb=[[]]+[1,2,3]
bb
# Out:
# [[], 1, 2, 3]

# %%
n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
graph=defaultdict(dict)

for stt,end,fare in fares:
        graph[stt][end]=fare
        graph[end][stt]=fare
        
print(graph)
for key,value in graph[1].items():
    print(key,value)
# Out:
# defaultdict(<class 'dict'>, {4: {1: 10, 6: 50, 2: 66}, 1: {4: 10, 3: 41, 5: 24, 6: 25}, 3: {5: 24, 1: 41, 2: 22}, 5: {3: 24, 6: 2, 1: 24}, 6: {5: 2, 4: 50, 1: 25}, 2: {4: 66, 3: 22}})
# 4 10
# 3 41
# 5 24
# 6 25

# %%
import heapq         

def solution(n, s, a, b, fares):
    
    graph = [[] for _ in range(n)]
    for x,y,z in fares:
        graph[x-1].append((z,y-1))
        graph[y-1].append((z,x-1))

    
    inf_v=20000001
    temp_sum = []
    
    for tr in range(n):
        q=[(0,tr)]
        visit=[True]*len(graph)
        dp = [float('inf')]*len(graph) 
        dp[tr]=0 # transfer위치 잡기
        while q: 
            fare,destin = heapq.heappop(q) 
            if visit[destin] == True: 
                visit[destin]=False
                for value,key in graph[destin]: 
                    if dp[key] > value + dp[destin]: 
                        dp[key] = value + dp[destin] 
                        heapq.heappush(q,(dp[key],key)) 
        temp_sum.append(dp[a-1]+dp[b-1]+dp[s-1]) 
    answer = min(temp_sum) 

    return answer 
n= 6
s= 4
a= 6
b= 2
fares= [[4, 1, 10], [3, 5, 24], [5, 6, 2], [3, 1, 41], [5, 1, 24], [4, 6, 50], [2, 4, 66], [2, 3, 22], [1, 6, 25]]
print(solution(n, s, a, b, fares))
# Out:
# 82
